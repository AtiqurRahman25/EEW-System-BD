# %%
# !git clone https://github.com/AtiqurRahman25/EEW-System-BD.git
# Out:
# Cloning into 'EEW-System-BD'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 6), reused 11 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 9.05 KiB | 4.53 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd EEW-System-BD
# Out:
# /content/EEW-System-BD

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !ls
# Out:
# LICENSE  modelTrain_VS.py  README.md

# %%
# !mv /content/modelTrain_Colab.ipynb /content/EEW-System-BD/
# Out:
# mv: cannot stat '/content/modelTrain_Colab.ipynb': No such file or directory
